# %%
# !pip install transformers

# %%
import os

os.environ["HF_TOKEN"] = "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"

# %%
model_name="google/gemma-3-1b-it"

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)

# %%
input_prompt = [
    "Hey there!"
]

# %%
tokenized = tokenizer(input_prompt,return_tensors="pt")

# %%
tokenized["input_ids"]
# Out:
# tensor([[     2,  17531,    993, 236888]])

# %%
import torch

model= AutoModelForCausalLM.from_pretrained(
    model_name,
    dtype=torch.bfloat16
)
# Out:
# Loading weights:   0%|          | 0/340 [00:00<?, ?it/s]

# %%
gen_result = model.generate(tokenized['input_ids'], max_new_tokens=25)

# %%
output = tokenizer.batch_decode(gen_result)

# %%
output
# Out:
# ["<bos>Hey there! 👋\n\nI'm here to assist you with whatever you need. I can help you with:\n\n*   **Writing"]
